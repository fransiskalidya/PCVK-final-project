# %% [markdown]
# <a href="https://colab.research.google.com/github/fransiskalidya/PCVK-final-project/blob/master/oil_storage_tank_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
para = cv2.imread('/content/drive/MyDrive/PCVK/Tubes/02_5_0.jpg')
gray = cv2.cvtColor(para,cv2.COLOR_BGR2GRAY) #Görüntüyü griye çevirdik
gray = cv2.medianBlur(gray,5) #Blur yaparak görüntüdeki kirliliği azalttık

circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT,1,120, param1=400,param2=30,minRadius=5,maxRadius=80)
circles_round = np.uint16(np.around(circles))

for i in circles_round[0, : ]:
    cv2.circle(para, (i[0],i[1]),i[2],(50,200,200),5)
    cv2.circle(para,(i[0],i[1]),2,(255,0,0),3)

print(circles.shape)
print(circles_round)
print(str(circles_round.shape[1]) + ' adet para bulundu.')

cv2_imshow(para)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (1, 2, 3)
# [[[168 434  63]
#   [294 200  65]]]
# 2 adet para bulundu.
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FCCF4E48810>
